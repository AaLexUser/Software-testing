# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
x = np.append(x, [np.nan, 1])
x = np.round(x, 5)
df = pd.DataFrame({'x': x})
df.to_csv('../src/test/resources/integration/integrationIn.csv', index=False, na_rep='NaN')

# %%
for i in x:
    if(i <= 0):
        if(i % math.pi == 0):
            y.append(np.nan)
        else:
            try:
                # y.append( ((sec(i) ** 3) / csc(i)) / (math.sin(i) + math.tan(i)) )
                y.append(sec(i) - csc(i))
            except ZeroDivisionError:
                y.append(np.nan)
    else:
        if i == 1 :
            y.append(np.nan)
        else:
            try:
                # y.append( (( ( ( log3(i) ** 3 ) / math.log(i) ) / (math.log(i) * log3(i))) - log5(i)) - log5(i))
                y.append(log3(i) - log5(i) - log5(i))
            except ZeroDivisionError:
                y.append(np.nan)

# %%
def sec(x):
    cosRes = math.sin(x)
    if abs(cosRes) < 1e-5:
        return math.nan
    return 1/math.cos(x)
def csc(x):
    sinRes = math.sin(x)
    if abs(sinRes) < 1e-5:
        return math.nan
    return 1/math.sin(x)

def log3(x):
    return math.log(x, 3)
def log5(x):
    return math.log(x, 5)

x_list = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
x_list = np.append(x, [np.nan])
y_list = np.zeros(len(x_list))
# complex function
for x, y in zip(x_list, y_list):
    if(x <= 0):
        y = sec(x) - csc(x)
    else:
        y = log3(x) - log5(x) - log5(x)

df = pd.DataFrame({'x': x_list, 'y': y_list})
df.to_csv('../src/test/resources/integration/myFunc.csv', index=False, na_rep='NaN')
display(df)

plt.plot(x_list, y_list)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
#             x    y
# 0   -6.283185  0.0
# 1   -6.251769  0.0
# 2   -6.220353  0.0
# 3   -6.188938  0.0
# 4   -6.157522  0.0
# ..        ...  ...
# 397  6.188938  0.0
# 398  6.220353  0.0
# 399  6.251769  0.0
# 400       NaN  0.0
# 401       NaN  0.0
#
# [402 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
x = np.append(x, [np.nan, 1])
x = np.round(x, 5)
y = np.log(x) / np.log(5)
# x = np.round(x, 5)
    

df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/integration/log5.csv', index=False, na_rep='NaN')
display(df)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/2916809620.py:4: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x) / np.log(5)
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/2916809620.py:4: RuntimeWarning: invalid value encountered in log
#   y = np.log(x) / np.log(5)
#            x      f(x)
# 0   -6.28319       NaN
# 1   -6.25177       NaN
# 2   -6.22035       NaN
# 3   -6.18894       NaN
# 4   -6.15752       NaN
# ..       ...       ...
# 397  6.18894  1.132547
# 398  6.22035  1.135692
# 399  6.25177  1.138823
# 400      NaN       NaN
# 401  1.00000  0.000000
#
# [402 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
x = np.append(x, [np.nan, 1])
x = np.round(x, 5)
y = np.log(x) / np.log(3)
# x = np.round(x, 5)
    

df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/integration/log3.csv', index=False, na_rep='NaN')
display(df)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/723419256.py:4: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x) / np.log(3)
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/723419256.py:4: RuntimeWarning: invalid value encountered in log
#   y = np.log(x) / np.log(3)
#            x      f(x)
# 0   -6.28319       NaN
# 1   -6.25177       NaN
# 2   -6.22035       NaN
# 3   -6.18894       NaN
# 4   -6.15752       NaN
# ..       ...       ...
# 397  6.18894  1.659151
# 398  6.22035  1.663759
# 399  6.25177  1.668345
# 400      NaN       NaN
# 401  1.00000  0.000000
#
# [402 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
x = np.append(x, [np.nan, 1])
x = np.round(x, 5)
x = np.append(x, [3, 5])
y = np.log(x)
# x = np.round(x, 5)
    

df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/integration/natlog.csv', index=False, na_rep='NaN')
display(df)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/1333796670.py:5: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/1333796670.py:5: RuntimeWarning: invalid value encountered in log
#   y = np.log(x)
#            x      f(x)
# 0   -6.28319       NaN
# 1   -6.25177       NaN
# 2   -6.22035       NaN
# 3   -6.18894       NaN
# 4   -6.15752       NaN
# ..       ...       ...
# 399  6.25177  1.832865
# 400      NaN       NaN
# 401  1.00000  0.000000
# 402  3.00000  1.098612
# 403  5.00000  1.609438
#
# [404 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
x = np.append(x, [np.nan, 1])
x = np.round(x, 5)
cosRes = np.cos(x)
sinRes = np.sin(x)
y = np.where(abs(cosRes) < 1e-5, np.nan, sinRes / cosRes)
# x = np.round(x, 5)

df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/integration/tangent.csv', index=False, na_rep='NaN')
display(df)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
#            x      f(x)
# 0   -6.28319 -0.000005
# 1   -6.25177  0.031426
# 2   -6.22035  0.062918
# 3   -6.18894  0.094525
# 4   -6.15752  0.126331
# ..       ...       ...
# 397  6.18894 -0.094525
# 398  6.22035 -0.062918
# 399  6.25177 -0.031426
# 400      NaN       NaN
# 401  1.00000  1.557408
#
# [402 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
x = np.append(x, [np.nan, 1])
x = np.round(x, 5)
y = np.cos(x)
# x = np.round(x, 5)

df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/integration/cosine.csv', index=False, na_rep='NaN')
display(df)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
#            x      f(x)
# 0   -6.28319  1.000000
# 1   -6.25177  0.999507
# 2   -6.22035  0.998027
# 3   -6.18894  0.995562
# 4   -6.15752  0.992115
# ..       ...       ...
# 397  6.18894  0.995562
# 398  6.22035  0.998027
# 399  6.25177  0.999507
# 400      NaN       NaN
# 401  1.00000  0.540302
#
# [402 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
xx = np.arange(-2*math.pi, 2*math.pi, math.pi/100 + math.pi / 2)
x = np.append(x, xx)
x = np.append(x, [np.nan, 1])
x = np.round(x, 5)
y = np.sin(x)
# x = np.round(x, 5)

df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/integration/sine.csv', index=False, na_rep='NaN')
display(df)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
#            x      f(x)
# 0   -6.28319 -0.000005
# 1   -6.25177  0.031410
# 2   -6.22035  0.062794
# 3   -6.18894  0.094106
# 4   -6.15752  0.125335
# ..       ...       ...
# 405  1.72788  0.987688
# 406  3.33009 -0.187383
# 407  4.93230 -0.975917
# 408      NaN       NaN
# 409  1.00000  0.841471
#
# [410 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
x = np.append(x, [np.nan, 1])
x = np.round(x, 5)
sinRes = np.sin(x)
y = np.where(abs(sinRes) < 1e-5, np.nan, 1 / sinRes)
# x = np.round(x, 5)

df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/integration/cosecant.csv', index=False, na_rep='NaN')
display(df)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/4217646853.py:5: RuntimeWarning: divide by zero encountered in divide
#   y = np.where(abs(sinRes) < 1e-5, np.nan, 1 / sinRes)
#            x       f(x)
# 0   -6.28319        NaN
# 1   -6.25177  31.836853
# 2   -6.22035  15.925097
# 3   -6.18894  10.626332
# 4   -6.15752   7.978629
# ..       ...        ...
# 397  6.18894 -10.626332
# 398  6.22035 -15.925097
# 399  6.25177 -31.836853
# 400      NaN        NaN
# 401  1.00000   1.188395
#
# [402 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/100)
x = np.append(x, [np.nan, 1])
x = np.round(x, 5)
cosRes = np.cos(x)
y = np.where(abs(cosRes) < 1e-5, np.nan, 1 / cosRes)
# x = np.round(x, 5)

df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/integration/secant.csv', index=False, na_rep='NaN')
display(df)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
#            x      f(x)
# 0   -6.28319  1.000000
# 1   -6.25177  1.000494
# 2   -6.22035  1.001977
# 3   -6.18894  1.004458
# 4   -6.15752  1.007948
# ..       ...       ...
# 397  6.18894  1.004458
# 398  6.22035  1.001977
# 399  6.25177  1.000494
# 400      NaN       NaN
# 401  1.00000  1.850816
#
# [402 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/20)
x = np.append(x, [np.nan])
cosRes = np.cos(x)
sinRes = np.sin(x)
y = np.where(abs(cosRes) < 1e-5, np.nan, sinRes / cosRes)
    
df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/tangent.csv', index=False, na_rep='NaN')
display(df)
# Out:
#            x          f(x)
# 0  -6.283185  2.449294e-16
# 1  -6.126106  1.583844e-01
# 2  -5.969026  3.249197e-01
# 3  -5.811946  5.095254e-01
# 4  -5.654867  7.265425e-01
# ..       ...           ...
# 76  5.654867 -7.265425e-01
# 77  5.811946 -5.095254e-01
# 78  5.969026 -3.249197e-01
# 79  6.126106 -1.583844e-01
# 80       NaN           NaN
#
# [81 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/20)
x = np.append(x, [np.nan])
cosRes = np.cos(x)
sinRes = np.sin(x)
y = np.where(abs(cosRes) < 1e-5, np.nan, 1 / cosRes)
    
df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/secant.csv', index=False, na_rep='NaN')
display(df)
# Out:
#            x      f(x)
# 0  -6.283185  1.000000
# 1  -6.126106  1.012465
# 2  -5.969026  1.051462
# 3  -5.811946  1.122326
# 4  -5.654867  1.236068
# ..       ...       ...
# 76  5.654867  1.236068
# 77  5.811946  1.122326
# 78  5.969026  1.051462
# 79  6.126106  1.012465
# 80       NaN       NaN
#
# [81 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/20)
x = np.append(x, [np.nan])
cosRes = np.cos(x)
sinRes = np.sin(x)
y = np.where(abs(sinRes) < 1e-5, np.nan, 1 / sinRes)
    
df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/cosecant.csv', index=False, na_rep='NaN')
display(df)
# Out:
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/780394872.py:5: RuntimeWarning: divide by zero encountered in divide
#   y = np.where(abs(sinRes) < 1e-5, np.nan, 1 / sinRes)
#            x      f(x)
# 0  -6.283185       NaN
# 1  -6.126106  6.392453
# 2  -5.969026  3.236068
# 3  -5.811946  2.202689
# 4  -5.654867  1.701302
# ..       ...       ...
# 76  5.654867 -1.701302
# 77  5.811946 -2.202689
# 78  5.969026 -3.236068
# 79  6.126106 -6.392453
# 80       NaN       NaN
#
# [81 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/20)
x = np.append(x, [np.nan])
y = np.sin(x)
    
df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/sine.csv', index=False, na_rep='NaN')
display(df)
# Out:
#            x          f(x)
# 0  -6.283185  2.449294e-16
# 1  -6.126106  1.564345e-01
# 2  -5.969026  3.090170e-01
# 3  -5.811946  4.539905e-01
# 4  -5.654867  5.877853e-01
# ..       ...           ...
# 76  5.654867 -5.877853e-01
# 77  5.811946 -4.539905e-01
# 78  5.969026 -3.090170e-01
# 79  6.126106 -1.564345e-01
# 80       NaN           NaN
#
# [81 rows x 2 columns]

# %%
x = np.arange(-2*math.pi, 2*math.pi, math.pi/20)
x = np.append(x, [np.nan])
y = np.cos(x)
    
df = pd.DataFrame({'x': x, 'f(x)': y})
# Save to CSV
df.to_csv('../src/test/resources/cosine.csv', index=False, na_rep='NaN')
display(df)
# Out:
#            x      f(x)
# 0  -6.283185  1.000000
# 1  -6.126106  0.987688
# 2  -5.969026  0.951057
# 3  -5.811946  0.891007
# 4  -5.654867  0.809017
# ..       ...       ...
# 76  5.654867  0.809017
# 77  5.811946  0.891007
# 78  5.969026  0.951057
# 79  6.126106  0.987688
# 80       NaN       NaN
#
# [81 rows x 2 columns]

# %%
x = np.arange(-100, 100, 0.1)
x = np.append(x, [np.nan, np.inf])
x = np.round(x, 2)
y = np.log(x)
    
df = pd.DataFrame({'x': x, 'f(x)': y})

df['f(x)'] = np.where(y == np.inf, 'Infinity', y)
df['f(x)'] = np.where(y == -np.inf, '-Infinity', y)
df['x'] = np.where(np.isinf(x), 'Infinity', x)
df['f(x)'] = np.where(np.isnan(y), 'NaN', df['f(x)'])
df['x'] = np.where(np.isnan(x), 'NaN', df['x'])
# Save to CSV
df.to_csv('../src/test/resources/natlog.csv', index=False)
display(df)
# Out:
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/2976536948.py:4: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/2976536948.py:4: RuntimeWarning: invalid value encountered in log
#   y = np.log(x)
#              x               f(x)
# 0       -100.0                NaN
# 1        -99.9                NaN
# 2        -99.8                NaN
# 3        -99.7                NaN
# 4        -99.6                NaN
# ...        ...                ...
# 1997      99.7  4.602165676967792
# 1998      99.8  4.603168183317418
# 1999      99.9  4.604169685654508
# 2000       NaN                NaN
# 2001  Infinity                inf
#
# [2002 rows x 2 columns]

# %%
x = np.arange(-10, 100, 0.1)
x = np.append(x, [np.nan, np.inf])
x = np.round(x, 2)
y = np.log(x) / np.log(3)
df = pd.DataFrame({'x': x, 'f(x)': y})

df['f(x)'] = np.where(y == np.inf, 'Infinity', y)
df['f(x)'] = np.where(y == -np.inf, '-Infinity', y)
df['x'] = np.where(np.isinf(x), 'Infinity', x)
df['f(x)'] = np.where(np.isnan(y), 'NaN', df['f(x)'])
df['x'] = np.where(np.isnan(x), 'NaN', df['x'])
# Save to CSV
df.to_csv('../src/test/resources/log3.csv', index=False)
display(df)
# Out:
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/1003226545.py:4: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x) / np.log(3)
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/1003226545.py:4: RuntimeWarning: invalid value encountered in log
#   y = np.log(x) / np.log(3)
#              x               f(x)
# 0        -10.0                NaN
# 1         -9.9                NaN
# 2         -9.8                NaN
# 3         -9.7                NaN
# 4         -9.6                NaN
# ...        ...                ...
# 1097      99.7  4.189071726611738
# 1098      99.8  4.189984247216111
# 1099      99.9  4.190895853928888
# 1100       NaN                NaN
# 1101  Infinity                inf
#
# [1102 rows x 2 columns]

# %%
x = np.arange(-10, 100, 0.1)
x = np.append(x, [np.nan, np.inf])
x = np.round(x, 2)
y = np.log(x) / np.log(5)
df = pd.DataFrame({'x': x, 'f(x)': y})

df['f(x)'] = np.where(y == np.inf, 'Infinity', y)
df['f(x)'] = np.where(y == -np.inf, '-Infinity', y)
df['x'] = np.where(np.isinf(x), 'Infinity', x)
df['f(x)'] = np.where(np.isnan(y), 'NaN', df['f(x)'])
df['x'] = np.where(np.isnan(x), 'NaN', df['x'])
# Save to CSV
df.to_csv('../src/test/resources/log5.csv', index=False)
display(df)
# Out:
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/798824784.py:4: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x) / np.log(5)
# /var/folders/zd/38wccmwn1p9fnwfx4yp0lpr80000gn/T/ipykernel_42187/798824784.py:4: RuntimeWarning: invalid value encountered in log
#   y = np.log(x) / np.log(5)
#              x                f(x)
# 0        -10.0                 NaN
# 1         -9.9                 NaN
# 2         -9.8                 NaN
# 3         -9.7                 NaN
# 4         -9.6                 NaN
# ...        ...                 ...
# 1097      99.7   2.859486309731275
# 1098      99.8  2.8601092019484153
# 1099      99.9  2.8607314703374924
# 1100       NaN                 NaN
# 1101  Infinity                 inf
#
# [1102 rows x 2 columns]

# %%
df = pd.read_csv('../src/test/resources/csvOut/myFunc.csv')
plt.plot(df['x'], df['y'])
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
plt.axis([-10, 10, -3, 10])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('График функции полученный из csv-выгрузки')
plt.savefig('image/myFunc.png')
plt.show()

# %%
eps = 1e-5

def sec(x):
    cosRes = math.cos(x)
    if abs(cosRes) < eps:
        return math.nan
    return 1/cosRes
def csc(x):
    sinRes = math.sin(x)
    if abs(sinRes) < eps:
        return math.nan
    return 1/sinRes

def log3(x):
    return math.log(x, 3)
def log5(x):
    return math.log(x, 5)
def log10(x):
    return math.log(x, 10)

x_list = np.arange(-100, 100, 0.0001)
x_list = np.append(x_list, [np.nan])
x_list = np.round(x_list, 5)
y_list = np.zeros(len(x_list))
# complex function
for i, (x, y) in enumerate(zip(x_list, y_list)):
    if( x == -10):
        print("x = 2.301")
    if x <= 0:
        if abs(x % math.pi) < 1e-5:
            y_list[i] = math.nan
        elif abs(x % math.pi - math.pi/2) < 1e-5:
            y_list[i] = math.nan
        elif abs(x % math.pi + math.pi/2) < 1e-5:
            y_list[i] = math.nan
        else:
            try: y_list[i] = ((sec(x) ** 3) / csc(x)) / (math.sin(x) + math.tan(x))
            except: print("Error at x = ", x)

    else:
        try: 
            if x == 1:
               y_list[i] = math.nan
            else:
               y_list[i] = ( (( ( ( log3(x) ** 3 ) / math.log(x) ) / (math.log(x) * log3(x))) - log5(x)) - log5(x))
        except: print("Error at x = ", x)

y_list = np.round(y_list, 5)
# formatted_list = ['{:0,.3f}'.format(num) for num in x_list]
df = pd.DataFrame({'x': x_list, 'y': y_list})
plt.plot(x_list, y_list, color='red')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
plt.axis([-10, 10, -3, 10])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('Эталонный график функции')
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.savefig('image/myFuncIdeal.png')
plt.show()
# Out:
# x = 2.301

# %%
df = pd.read_csv('../src/test/resources/csvOut/Sine.csv')
plt.plot(df['x'], df['y'])
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
plt.axis([-2*math.pi, 2*math.pi, -1.5, 1.5])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('График Sine полученный из csv-выгрузки')
plt.savefig('image/Sine.png')
plt.show()

# %%
df = pd.read_csv('../src/test/resources/csvOut/Cosine.csv')
plt.plot(df['x'], df['y'])
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
plt.axis([-2*math.pi, 2*math.pi, -1.5, 1.5])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('График Cosine полученный из csv-выгрузки')
plt.savefig('image/Cosine.png')
plt.show()

# %%
df = pd.read_csv('../src/test/resources/csvOut/Secant.csv')
plt.plot(df['x'], df['y'])
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
plt.axis([-2*math.pi, 2*math.pi, -10, 10])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('График Secant полученный из csv-выгрузки')
plt.savefig('image/Secant.png')
plt.show()

# %%
df = pd.read_csv('../src/test/resources/csvOut/Cosecant.csv')
plt.plot(df['x'], df['y'])
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
plt.axis([-2*math.pi, 2*math.pi, -10, 10])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('График Cosecant полученный из csv-выгрузки')
plt.savefig('image/Cosecant.png')
plt.show()

# %%
df = pd.read_csv('../src/test/resources/csvOut/Tangent.csv')
plt.plot(df['x'], df['y'])
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
plt.axis([-2*math.pi, 2*math.pi, -10, 10])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('График Tangent полученный из csv-выгрузки')
plt.savefig('image/Tangent.png')
plt.show()

# %%
df = pd.read_csv('../src/test/resources/csvOut/NaturalLogarithm.csv')
plt.plot(df['x'], df['y'])
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
# plt.axis([-2*math.pi, 2*math.pi, -1, 10])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('График NaturalLogarithm полученный из csv-выгрузки')
plt.savefig('image/NaturalLogarithm.png')
plt.show()

# %%
df = pd.read_csv('../src/test/resources/csvOut/LogarithmBase3.csv')
plt.plot(df['x'], df['y'])
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
# plt.axis([-2*math.pi, 2*math.pi, -1, 10])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('График LogarithmBase3 полученный из csv-выгрузки')
plt.savefig('image/LogarithmBase3.png')
plt.show()

# %%
df = pd.read_csv('../src/test/resources/csvOut/LogarithmBase5.csv')
plt.plot(df['x'], df['y'])
plt.rcParams['savefig.dpi'] = 300
plt.rcParams['figure.dpi'] = 300
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
#fix scale
# plt.axis([-2*math.pi, 2*math.pi, -1, 10])
#minor grid
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title('График LogarithmBase5 полученный из csv-выгрузки')
plt.savefig('image/LogarithmBase5.png')
plt.show()
